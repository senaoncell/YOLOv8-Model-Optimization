# %% [markdown]
# ## YOLOv8 | Pretrained Model Comparison

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/YOLOv8 Model Optimization/01_Pretrained Model Comparision
# Out:
# /content/drive/MyDrive/YOLOv8 Model Optimization/01_Pretrained Model Comparision

# %%
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.9 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 36.6/112.6 GB disk)

# %% [markdown]
# ## mAP

# %%
# !yolo detect val model="yolov8n.pt" data=coco128.yaml iou=0.5 name=yolov8n_test
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 101MB/s]
# Ultralytics 8.3.9 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# Dataset 'coco128.yaml' images not found ⚠️, missing path '/content/drive/MyDrive/YOLOv8 Model Optimization/01_Pretrained Model Comparision/datasets/coco128/images/train2017'
# ...
# 100% 6.66M/6.66M [00:00<00:00, 103MB/s]
# Unzipping /content/drive/MyDrive/YOLOv8 Model Optimization/01_Pretrained Model Comparision/datasets/coco128.zip to /content/drive/MyDrive/YOLOv8 Model Optimization/01_Pretrained Model Comparision/datasets/coco128...: 100% 263/263 [00:01<00:00, 134.94file/s]
# Dataset download success ✅ (2.9s), saved to /content/drive/MyDrive/YOLOv8 Model Optimization/01_Pretrained Model Comparision/datasets
#
# ...
# 100% 755k/755k [00:00<00:00, 22.6MB/s]
# ...

# %%
# !yolo detect val model="yolov8s.pt" data=coco128.yaml iou=0.5 name=yolov8s_test
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 162MB/s]
# Ultralytics 8.3.9 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11,156,544 parameters, 0 gradients, 28.6 GFLOPs
# val: Scanning /content/drive/MyDrive/YOLOv8 Model Optimization/01_Pretrained Model Comparision/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:04<00:00,  1.66it/s]
#                    all        128        929      0.808      0.672      0.768      0.583
#                 person         61        254      0.908      0.681      0.831      0.623
#                bicycle          3          6          1      0.328      0.492      0.274
#                    car         12         46      0.845      0.217      0.408      0.233
# ...

# %%
# !yolo detect val model="yolov8m.pt" data=coco128.yaml iou=0.5 name=yolov8m_test
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 130MB/s]
# Ultralytics 8.3.9 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25,886,080 parameters, 0 gradients, 78.9 GFLOPs
# val: Scanning /content/drive/MyDrive/YOLOv8 Model Optimization/01_Pretrained Model Comparision/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:05<00:00,  1.48it/s]
#                    all        128        929      0.724      0.727      0.782      0.602
#                 person         61        254      0.866      0.738      0.858      0.644
#                bicycle          3          6          1      0.626       0.79       0.58
#                    car         12         46      0.796       0.34      0.567      0.308
# ...

# %%
# !yolo detect val model="yolov8l.pt" data=coco128.yaml iou=0.5 name=yolov8l_test
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 208MB/s]
# Ultralytics 8.3.9 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43,668,288 parameters, 0 gradients, 165.2 GFLOPs
# val: Scanning /content/drive/MyDrive/YOLOv8 Model Optimization/01_Pretrained Model Comparision/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:06<00:00,  1.27it/s]
#                    all        128        929      0.713      0.783      0.832      0.648
#                 person         61        254      0.825      0.777      0.855      0.666
#                bicycle          3          6      0.845      0.667       0.74      0.518
#                    car         12         46       0.86      0.522       0.65       0.35
# ...

# %%
# !yolo detect val model="yolov8x.pt" data=coco128.yaml iou=0.5 name=yolov8x_test
# Out:
# ...
# 100% 131M/131M [00:01<00:00, 124MB/s]
# Ultralytics 8.3.9 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x summary (fused): 268 layers, 68,200,608 parameters, 0 gradients, 257.8 GFLOPs
# val: Scanning /content/drive/MyDrive/YOLOv8 Model Optimization/01_Pretrained Model Comparision/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:08<00:00,  1.08s/it]
#                    all        128        929      0.838      0.688      0.827      0.657
#                 person         61        254      0.951      0.681       0.87      0.671
#                bicycle          3          6      0.825        0.5      0.741      0.569
#                    car         12         46          1       0.26      0.659       0.37
#             motorcycle          4          5       0.91          1      0.995      0.815
# ...

# %% [markdown]
# ## FPS

# %%
from helper import process_video

# %% [markdown]
# YOLOv8n

# %%
video_path="./inference/test.mp4"
save_path="./results/test_yolov8n_results.mp4"
model_path="./yolov8n.pt"
image_size=320
half_precision=False

process_video(video_path,model_path,save_path,image_size,half_precision)
# Out:
# [INFO]: Video is processing..
# [INFO]: Processing task is completed successfully!..
# Result video is saved in: ./results/test_yolov8n_results.mp4

# %% [markdown]
# YOLOv8s

# %%
video_path="./inference/test.mp4"
save_path="./results/test_yolov8s_results.mp4"
model_path="./yolov8s.pt"
image_size=320
half_precision=False

process_video(video_path,model_path,save_path,image_size,half_precision)
# Out:
# [INFO]: Video is processing..
# [INFO]: Processing task is completed successfully!..
# Result video is saved in: ./results/test_yolov8s_results.mp4

# %% [markdown]
# YOLOv8m

# %%
video_path="./inference/test.mp4"
save_path="./results/test_yolov8m_results.mp4"
model_path="./yolov8m.pt"
image_size=320
half_precision=False

process_video(video_path,model_path,save_path,image_size,half_precision)
# Out:
# [INFO]: Video is processing..
# [INFO]: Processing task is completed successfully!..
# Result video is saved in: ./results/test_yolov8m_results.mp4

# %% [markdown]
# YOLOv8l

# %%
video_path="./inference/test.mp4"
save_path="./results/test_yolov8l_results.mp4"
model_path="./yolov8l.pt"
image_size=320
half_precision=False

process_video(video_path,model_path,save_path,image_size,half_precision)
# Out:
# [INFO]: Video is processing..
# [INFO]: Processing task is completed successfully!..
# Result video is saved in: ./results/test_yolov8l_results.mp4

# %% [markdown]
# YOLOv8x

# %%
video_path="./inference/test.mp4"
save_path="./results/test_yolov8x_results.mp4"
model_path="./yolov8x.pt"
image_size=320
half_precision=False

process_video(video_path,model_path,save_path,image_size,half_precision)
# Out:
# [INFO]: Video is processing..
# [INFO]: Processing task is completed successfully!..
# Result video is saved in: ./results/test_yolov8x_results.mp4
